# %%
import pandas as pd
from pandas import DataFrame, Series
data = pd.read_csv('../data/cct_corr.csv', names=['0.25', '0.5', '1', '1.5', '2', '2.5', 'grade'])
print(data.corr())
# Out:
#            0.25       0.5         1       1.5         2       2.5     grade
# 0.25   1.000000  0.969369  0.880295  0.816202  0.753870  0.693553  0.278755
# 0.5    0.969369  1.000000  0.950419  0.890935  0.825920  0.763777  0.291440
# 1      0.880295  0.950419  1.000000  0.976641  0.933371  0.889683  0.251412
# 1.5    0.816202  0.890935  0.976641  1.000000  0.980492  0.952150  0.225475
# 2      0.753870  0.825920  0.933371  0.980492  1.000000  0.983721  0.215144
# 2.5    0.693553  0.763777  0.889683  0.952150  0.983721  1.000000  0.168045
# grade  0.278755  0.291440  0.251412  0.225475  0.215144  0.168045  1.000000
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.heatmap(data = data.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='Blues')
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
