# %%
import pandas as pd
from pandas import DataFrame, Series
data = pd.read_csv('../data/cct_corr.csv', names=['0.25', '0.5', '1', '1.5', '2', '2.5', 'grade'])
print(data.corr())
# Out:
#            0.25       0.5         1       1.5         2       2.5     grade
# 0.25   1.000000  0.952932  0.838128  0.771749  0.727016  0.676401  0.538368
# 0.5    0.952932  1.000000  0.929923  0.858860  0.797131  0.731926  0.500338
# 1      0.838128  0.929923  1.000000  0.963846  0.909943  0.857912  0.475916
# 1.5    0.771749  0.858860  0.963846  1.000000  0.970997  0.931462  0.500532
# 2      0.727016  0.797131  0.909943  0.970997  1.000000  0.970473  0.508321
# 2.5    0.676401  0.731926  0.857912  0.931462  0.970473  1.000000  0.483289
# grade  0.538368  0.500338  0.475916  0.500532  0.508321  0.483289  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.heatmap(data = data.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='Blues')
